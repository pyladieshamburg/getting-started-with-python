# %% [markdown]
# Let's try something cool!
#
# Visualising missing data with [missingno](https://github.com/ResidentMario/missingno)
#
# We are just going to copy paste some of the commands for starters. Use your newly created Python Environemnt for this.

# %% [markdown]
# In your new *my-virtual-env-3.6.6* (or however you named it) run the following commands
#
# ```sh
# $ pip install numpy
# $ pip install quilt
# $ quilt install ResidentMario/missingno_data
# ```
#
# alternatively you can use install all the stuff from within a cell with *!pip..*

# %%
import numpy as np
from quilt.data.ResidentMario import missingno_data

collisions = missingno_data.nyc_collision_factors()
collisions = collisions.replace("nan", np.nan)

# %%
#Matrix
#The `msno.matrix` nullity matrix is a data-dense display which lets you quickly visually pick out patterns in
#data completion.
import missingno as msno
# %matplotlib inline
msno.matrix(collisions.sample(250))

# %% [markdown]
# ## Go try the other stuff in the missingno repo!!
